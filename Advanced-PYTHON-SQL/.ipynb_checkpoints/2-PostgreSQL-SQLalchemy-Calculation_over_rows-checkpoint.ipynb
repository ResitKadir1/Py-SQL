# %% [markdown]
# # QUIZ
#
# q-1--> Which keyword can be used with between _____ preceding and _____ following to create a sorted window frame that contains all rows?
#
# A-1-->unbounded
#
# q-2--> You have a column of values named 'data' that contains the numbers 10, 20, 30. What would be the result of this window function?
#
#  avg(data) over (order by data)
#
#  A-2-->10, 15, 20
#
#
# The ORDER BY clause in the OVER clause causes the window function to operate only on rows up to and including the current row in the frame.
#
#
# Q-3--> Which of these will create a five period moving average of the daily stock price data?
#
# A-3-->avg(stock_price) over (order by date rows between 2 preceding and 2 following)
#
#
# Q-4-->You have a data table that stores information about a wide variety of animals and their weights. Which window function will return the average weight for each species?
#
# A-4-->avg(weight) over (partition by species)
# Correct
#
# Creating segments within the window frame requires the PARTITION BY keywords.
#
#
# Q-5-->Why would you add a window clause to a query?
#
# A-5-->to create a window frame that's used by several window functions
#
# q-6---> Which clause turns an aggregate function into a window function?
#
# A-6--> OVER

# %% [markdown]
# Calculation_over_rows
#
# # connect the Database
#
# sqlalchemy is table based

# %%
from sqlalchemy import create_engine
import pandas as pd
# connection string: driver://username:password@server/database
engine = create_engine('postgresql+psycopg2://postgres:password@localhost/two_three')

# %% [markdown]
# # Queires

# %% [markdown]
# Windows function uses OVER class
# OVER calculate overall dataset,check if any product price over or below avarage
#
# #### instead group by use OVER

# %%
pd.read_sql_query(
        '''
        select sku,
            product_name,
            size,
            price,
            avg(price) over()
        from inventory.products
        ''', engine).head(2)
# Out:
#       sku product_name  size  price        avg
# 0  ALB008     Delicate     8  10.99  17.595263
# 1  ALB032     Delicate    32  18.99  17.595263

# %%
#partition
pd.read_sql_query(
        '''
select sku,
	product_name,
	size,
	category_id,
	price,
	avg(price) over(partition by size) as "average price for size",
	price - avg(price) over(partition by size) as "difference"
from inventory.products
order by sku, size;
        ''', engine).head(10)
# Out:
#       sku       product_name  size  category_id  price  \
# 0  ALB008           Delicate     8            1  10.99
# 1  ALB032           Delicate    32            1  18.99
# 2  ALB064           Delicate    64            1  22.99
# 3  ALB128           Delicate   128            1  26.99
# 4   BI008  Basil-Infused EVO     8            2  10.99
# 5   BI016  Basil-Infused EVO    16            2  14.99
# 6   BI032  Basil-Infused EVO    32            2  18.99
# 7   EV008       Extra Virgin     8            1   8.99
# 8   EV016       Extra Virgin    16            1  12.99
# 9   EV032       Extra Virgin    32            1  16.99
#
#    average price for size  difference
# 0               10.531667    0.458333
# 1               18.531667    0.458333
# 2               22.434444    0.555556
# 3               26.490000    0.500000
# 4               10.531667    0.458333
# 5               14.323333    0.666667
# 6               18.531667    0.458333
# 7               10.531667   -1.541667
# ...

# %%
#WINDOW kisaltma gibi dusun

#partition
pd.read_sql_query(
        '''
select sku,
	product_name,
	category_id,
	size,
	price,
	avg(price) over (xyz),
	min(price) over (xyz),
	max(price) over (xyz)
from inventory.products
window xyz as (partition by category_id)
order by sku, size ;

        ''', engine).head(10)
# Out:
#       sku       product_name  category_id  size  price        avg   min    max
# 0  ALB008           Delicate            1     8  10.99  18.518090  8.99  27.99
# 1  ALB032           Delicate            1    32  18.99  18.518090  8.99  27.99
# 2  ALB064           Delicate            1    64  22.99  18.518090  8.99  27.99
# 3  ALB128           Delicate            1   128  26.99  18.518090  8.99  27.99
# 4   BI008  Basil-Infused EVO            2     8  10.99  14.656667  8.99  19.99
# 5   BI016  Basil-Infused EVO            2    16  14.99  14.656667  8.99  19.99
# 6   BI032  Basil-Infused EVO            2    32  18.99  14.656667  8.99  19.99
# 7   EV008       Extra Virgin            1     8   8.99  18.518090  8.99  27.99
# 8   EV016       Extra Virgin            1    16  12.99  18.518090  8.99  27.99
# 9   EV032       Extra Virgin            1    32  16.99  18.518090  8.99  27.99

# %% [markdown]
# #### two table

# %%
pd.read_sql_query('select * from sales.order_lines', engine).head(3)
# Out:
#    order_id  line_id     sku  quantity
# 0       100        1  HOJ016         2
# 1       101        2  MAN128         2
# 2       101        3  MIS032         1

# %%
pd.read_sql_query('select * from inventory.products', engine).head(3)
# Out:
#       sku product_name  category_id  size  price
# 0  ALB008     Delicate            1     8  10.99
# 1  ALB032     Delicate            1    32  18.99
# 2  ALB064     Delicate            1    64  22.99

# %%
#SORT 

# OVER() --> get all
#
pd.read_sql_query(
        '''
SELECT 
    order_lines.order_id,
    order_lines.line_id,
    order_lines.sku,
    order_lines.quantity,
    
    products.price AS "price each",
    
    order_lines.quantity * products.price AS "line total",
    
    SUM (order_lines.quantity * products.price) 
        OVER (partition by order_id) AS "order total",
    SUM (order_lines.quantity * products.price) 
        OVER (partition by order_id ORDER BY line_id) AS "running total"

FROM sales.order_lines INNER JOIN inventory.products
    ON order_lines.sku = products.sku;

        ''', engine).head(10)
# Out:
#    order_id  line_id     sku  quantity  price each  line total  order total  \
# 0       100        1  HOJ016         2       15.99       31.98        31.98
# 1       101        2  MAN128         2       26.99       53.98        98.95
# 2       101        3  MIS032         1       18.99       18.99        98.95
# 3       101        4  PEN008         1       10.99       10.99        98.95
# 4       101        5   RI016         1       14.99       14.99        98.95
# 5       102        6  FCP128         2       24.99       49.98       222.88
# 6       102        7  FCP128         3       24.99       74.97       222.88
# 7       102        8  LGT016         3       12.99       38.97       222.88
# 8       102        9  MIS064         1       22.99       22.99       222.88
# 9       102       10  OBL008         3       11.99       35.97       222.88
#
#    running total
# 0          31.98
# 1          53.98
# 2          72.97
# 3          83.96
# 4          98.95
# 5          49.98
# ...

# %%
#MOvING AVARAGE,3 period leading sum, steps,100,101,101 =303
#                3,steps ,101,101,101 = 306
###
#3 period trailing sum	,nothing before -->100,second step before 100 current 101--> 201

##3 period moving average--> 100+101+101/3=100.5

pd.read_sql_query(
        '''
select order_id,
    sum(order_id) over (order by order_id rows between 0 preceding and 2 following)
        as "3 period leading sum",
    sum(order_id) over (order by order_id rows between 2 preceding and 0 following)
        as "3 period trailing sum",
        avg(order_id) over (order by order_id rows between 1 preceding and 1 following)
        as "3 period moving average"
from sales.orders;

        ''', engine).head(10)
# Out:
#    order_id  3 period leading sum  3 period trailing sum  \
# 0       100                   303                    100
# 1       101                   306                    201
# 2       102                   309                    303
# 3       103                   312                    306
# 4       104                   315                    309
# 5       105                   318                    312
# 6       106                   321                    315
# 7       107                   324                    318
# 8       108                   327                    321
# 9       109                   330                    324
#
#    3 period moving average
# 0                    100.5
# 1                    101.0
# 2                    102.0
# 3                    103.0
# 4                    104.0
# 5                    105.0
# 6                    106.0
# 7                    107.0
# 8                    108.0
# 9                    109.0

# %%
pd.read_sql_query('select * from sales.customers', engine).head(3)
# Out:
#   customer_id        company           address        city state    zip  \
# 0       FV418    Flavorville  798 Ravinia Road  Des Moines    IA  50320
# 1       WR421      Wild Rose   222 Dakota Lane   Kalamazoo    MI  49001
# 2       BX305  Bread Express     3362 Ute Loop      Tiffin    OH  44883
#
#    newsletter
# 0        True
# 1        True
# 2       False

# %%
pd.read_sql_query('select * from sales.orders', engine).head(3)
# Out:
#    order_id  order_date customer_id
# 0       100  2021-03-15       BX305
# 1       101  2021-03-17       GR208
# 2       102  2021-03-19       BV446

# %%
#LOCATION

#rows between unbounded preceding and unbounded following-->take considreation all rows in the frame

pd.read_sql_query(
        '''
select company,
        
    first_value(company) over(order by company
            rows between unbounded preceding and unbounded following),
    last_value(company) over(order by company
        rows between unbounded preceding and unbounded following),
            nth_value(company, 3) over(order by company
        rows between unbounded preceding and unbounded following)

from sales.customers
order by company;

select * from sales.orders;



select distinct customer_id,
    first_value(order_date) over (partition by customer_id order by order_date 
        rows between unbounded preceding and unbounded following),
    last_value(order_date) over (partition by customer_id order by order_date
        rows between unbounded preceding and unbounded following)

from sales.orders
order by customer_id;


        ''', engine).head(10)
# Out:
#   customer_id first_value  last_value
# 0       BV446  2021-03-19  2021-04-28
# 1       BX305  2021-03-15  2021-04-29
# 2       DF600  2021-03-21  2021-04-29
# 3       FV418  2021-03-20  2021-04-27
# 4       GR208  2021-03-17  2021-04-30
# 5       WR421  2021-03-23  2021-04-28

# %% [markdown]
# ### challenge -5 min
#
# *1-Use inventory.product to explore the two_three olive oil product data
#
# *2-Write query with window function that expands on the information for each product
#
# *3-Display the min max,and avarage price for each product, as well as the total count of products within the same category and ssize classification
#
# *Remeber to use a window clause when frames use the same parameters

# %%
pd.read_sql_query('select * from inventory.products', engine).head(3)
# Out:
#       sku product_name  category_id  size  price
# 0  ALB008     Delicate            1     8  10.99
# 1  ALB032     Delicate            1    32  18.99
# 2  ALB064     Delicate            1    64  22.99

# %%
pd.read_sql_query(
        '''
    SELECT  category_id,product_name,size,price,
            avg(price) over (xyz),
            min(price) over (xyz),
            max(price) over (xyz),
            COUNT(*) over (xyz)
            


    FROM inventory.products
    
    WINDOw xyz as (partition by category_id,size)
            order by category_id,product_name, size ;

        ''', engine).head(10)
# Out:
#    category_id  product_name  size  price        avg    min    max  count
# 0            1          Bold     8  11.99  10.490000   8.99  11.99     18
# 1            1          Bold    16  15.99  14.460588  12.99  15.99     17
# 2            1          Bold    32  19.99  18.490000  16.99  19.99     18
# 3            1          Bold    64  23.99  22.434444  20.99  23.99     18
# 4            1          Bold   128  27.99  26.490000  24.99  27.99     18
# 5            1      Delicate     8  10.99  10.490000   8.99  11.99     18
# 6            1      Delicate    32  18.99  18.490000  16.99  19.99     18
# 7            1      Delicate    64  22.99  22.434444  20.99  23.99     18
# 8            1      Delicate   128  26.99  26.490000  24.99  27.99     18
# 9            1  Extra Virgin     8   8.99  10.490000   8.99  11.99     18
